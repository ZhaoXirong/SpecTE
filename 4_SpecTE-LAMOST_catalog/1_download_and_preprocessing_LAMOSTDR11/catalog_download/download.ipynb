# %%
import wget
import os
import pickle
import json

# %%
# # 定义文件路径

# 定义文件路径
url_txt_path = r"G:\Star\4_SpecTE-LAMOST_catalog\1_download_and_preprocessing_LAMOSTDR11\catalog_download\download_url\5-6.txt"     # URL文件
download_path = r"G:\Star\4_SpecTE-LAMOST_catalog\1_download_and_preprocessing_LAMOSTDR11\catalog_download\FITS\5-6"        # 目标下载位置
progress_file = r'G:\Star\4_SpecTE-LAMOST_catalog\1_download_and_preprocessing_LAMOSTDR11\catalog_download\progress\download_progress_5-6.json'    # 保存下载进度log文件（保存进度，用于恢复下载）

# url_txt_path = "./download_url/5-6.txt"
# download_path = "./Fits/5-6"
# progress_file = "./Fits/download_progress_5-6.json"

# %% [markdown]
# # 开始下载

# %%
# 保存下载进程
def save_progress(progress, progress_file):
    with open(progress_file, 'w') as f:
        json.dump(progress, f)

# 加载下载进程
def load_progress(progress_file):
    if os.path.exists(progress_file):
        with open(progress_file, 'r') as f:
            return json.load(f)
    return {'completed': [], 'err_log': {}, 'n': 0}

def download_spectra(url_txt_path, download_path, progress_file):
    with open(url_txt_path, 'r') as f:
        err_list = []
        ls = []

        # 读到链接列表ls
        f.readline()  # 跳过第一行，如果需要
        while True:
            line = f.readline()
            if line:
                ls.append(line.strip())  # 去掉换行符
            else:
                break

    # Number of all spectra
    print("Number of spectra to download:", len(ls))
    
    # 防止出问题
    progress = load_progress(progress_file)
    completed = set(progress['completed'])
    err_log = progress['err_log']
    n = progress['n']

    for j in range(0, len(ls)):
        if j in completed:
            continue
        try:
            wget.download(ls[j], download_path)
            completed.add(j)
            if j % 20 == 0:  # 每下载20个保存一次进度
                save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)
        except Exception as e:
            print(f"|| {j} err: {e}")
            err_list.append(j)
            continue

    err_log[n] = err_list
    n += 1
    save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)

    # 失败处重新下载
    while len(err_list) > 5:
        final_err_list = []
        print("\n重新下载失败光谱")
        print("Number of err spectra to download:", len(err_list))
        for j in err_list:
            try:
                wget.download(ls[j], download_path)
                completed.add(j)
                save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)
            except Exception as e:
                print(f"|| {j} err: {e}")
                final_err_list.append(j)
                continue

        err_log[n] = final_err_list
        err_list = final_err_list
        n += 1
        save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)

    return err_log

# %%
#创建下载路径的文件夹
os.makedirs(download_path, exist_ok=True)

# 开始下载
error_log = download_spectra(url_txt_path, download_path, progress_file)
# Out:
# Number of spectra to download: 414781
# -1 / unknown|| 595 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 3256 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 8504 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 10259 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 11386 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 17653 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 17764 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 20474 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 20560 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 22611 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 34365 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 35760 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 37086 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 38973 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 43587 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 44082 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 47881 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 52689 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 73055 err: HTTP Error 502: Bad Gateway
# || 73056 err: HTTP Error 502: Bad Gateway
# || 73057 err: HTTP Error 502: Bad Gateway
# || 73058 err: HTTP Error 502: Bad Gateway
# || 73059 err: HTTP Error 502: Bad Gateway
# || 73060 err: HTTP Error 502: Bad Gateway
# || 73061 err: HTTP Error 502: Bad Gateway
# || 73062 err: HTTP Error 502: Bad Gateway
# || 73063 err: HTTP Error 502: Bad Gateway
# || 73064 err: HTTP Error 502: Bad Gateway
# || 73065 err: HTTP Error 502: Bad Gateway
# || 73066 err: HTTP Error 502: Bad Gateway
# || 73067 err: HTTP Error 502: Bad Gateway
# || 73068 err: HTTP Error 502: Bad Gateway
# || 73069 err: HTTP Error 502: Bad Gateway
# || 73070 err: HTTP Error 502: Bad Gateway
# || 73071 err: HTTP Error 502: Bad Gateway
# || 73072 err: HTTP Error 502: Bad Gateway
# || 73073 err: HTTP Error 502: Bad Gateway
# || 73074 err: HTTP Error 502: Bad Gateway
# || 73075 err: HTTP Error 502: Bad Gateway
# || 73076 err: HTTP Error 502: Bad Gateway
# || 73077 err: HTTP Error 502: Bad Gateway
# || 73078 err: HTTP Error 502: Bad Gateway
# || 73079 err: HTTP Error 502: Bad Gateway
# || 73080 err: HTTP Error 502: Bad Gateway
# || 73081 err: HTTP Error 502: Bad Gateway
# || 73082 err: HTTP Error 502: Bad Gateway
# || 73083 err: HTTP Error 502: Bad Gateway
# || 73084 err: HTTP Error 502: Bad Gateway
# || 73085 err: HTTP Error 502: Bad Gateway
# || 73086 err: HTTP Error 502: Bad Gateway
# || 73087 err: HTTP Error 502: Bad Gateway
# || 73088 err: HTTP Error 502: Bad Gateway
# || 73089 err: HTTP Error 502: Bad Gateway
# || 73090 err: HTTP Error 502: Bad Gateway
# || 73091 err: HTTP Error 502: Bad Gateway
# || 73092 err: HTTP Error 502: Bad Gateway
# || 73093 err: HTTP Error 502: Bad Gateway
# || 73094 err: HTTP Error 502: Bad Gateway
# || 73095 err: HTTP Error 502: Bad Gateway
# || 73096 err: HTTP Error 502: Bad Gateway
# || 73097 err: HTTP Error 502: Bad Gateway
# || 73098 err: HTTP Error 502: Bad Gateway
# -1 / unknown|| 134524 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 136807 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 137264 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 139755 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 159951 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 160475 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 160560 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 238527 err: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# || 238528 err: <urlopen error [Errno 11001] getaddrinfo failed>
# -1 / unknown|| 270141 err: HTTP Error 502: Bad Gateway
# || 270142 err: HTTP Error 502: Bad Gateway
# || 270143 err: HTTP Error 502: Bad Gateway
# || 270144 err: HTTP Error 502: Bad Gateway
# || 270145 err: HTTP Error 502: Bad Gateway
# || 270146 err: HTTP Error 502: Bad Gateway
# || 270147 err: HTTP Error 502: Bad Gateway
# || 270148 err: HTTP Error 502: Bad Gateway
# || 270149 err: HTTP Error 502: Bad Gateway
# || 270150 err: HTTP Error 502: Bad Gateway
# || 270151 err: HTTP Error 502: Bad Gateway
# || 270152 err: HTTP Error 502: Bad Gateway
# || 270153 err: HTTP Error 502: Bad Gateway
# || 270154 err: HTTP Error 502: Bad Gateway
# || 270155 err: HTTP Error 502: Bad Gateway
# || 270156 err: HTTP Error 502: Bad Gateway
# || 270157 err: HTTP Error 502: Bad Gateway
# || 270158 err: HTTP Error 502: Bad Gateway
# || 270159 err: HTTP Error 502: Bad Gateway
# || 270160 err: HTTP Error 502: Bad Gateway
# || 270161 err: HTTP Error 502: Bad Gateway
# || 270162 err: HTTP Error 502: Bad Gateway
# || 270163 err: HTTP Error 502: Bad Gateway
# || 270164 err: HTTP Error 502: Bad Gateway
# || 270165 err: HTTP Error 502: Bad Gateway
# || 270166 err: HTTP Error 502: Bad Gateway
# || 270167 err: HTTP Error 502: Bad Gateway
# || 270168 err: HTTP Error 502: Bad Gateway
# || 270169 err: HTTP Error 502: Bad Gateway
# || 270170 err: HTTP Error 502: Bad Gateway
# || 270171 err: HTTP Error 502: Bad Gateway
# || 270172 err: HTTP Error 502: Bad Gateway
# || 270173 err: HTTP Error 502: Bad Gateway
# -1 / unknown
