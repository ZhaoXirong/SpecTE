# %%
import wget
import os
import pickle
import json

# %%
# # 定义文件路径

# 定义文件路径
url_txt_path = r"G:\Star\4_SpecTE-LAMOST_catalog\1_download_and_preprocessing_LAMOSTDR11\catalog_download\download_url\13-16.txt"     # URL文件
download_path = r"G:\Star\4_SpecTE-LAMOST_catalog\1_download_and_preprocessing_LAMOSTDR11\catalog_download\FITS\13-16"        # 目标下载位置
progress_file = r'G:\Star\4_SpecTE-LAMOST_catalog\1_download_and_preprocessing_LAMOSTDR11\catalog_download\progress\download_progress_13-16.json'    # 保存下载进度log文件（保存进度，用于恢复下载）

# url_txt_path = "./download_url/5-6.txt"
# download_path = "./Fits/5-6"
# progress_file = "./Fits/download_progress_5-6.json"

# %% [markdown]
# # 开始下载

# %%
# 保存下载进程
def save_progress(progress, progress_file):
    with open(progress_file, 'w') as f:
        json.dump(progress, f)

# 加载下载进程
def load_progress(progress_file):
    if os.path.exists(progress_file):
        with open(progress_file, 'r') as f:
            return json.load(f)
    return {'completed': [], 'err_log': {}, 'n': 0}

def download_spectra(url_txt_path, download_path, progress_file):
    with open(url_txt_path, 'r') as f:
        err_list = []
        ls = []

        # 读到链接列表ls
        f.readline()  # 跳过第一行，如果需要
        while True:
            line = f.readline()
            if line:
                ls.append(line.strip())  # 去掉换行符
            else:
                break

    # Number of all spectra
    print("Number of spectra to download:", len(ls))
    
    # 防止出问题
    progress = load_progress(progress_file)
    completed = set(progress['completed'])
    err_log = progress['err_log']
    n = progress['n']

    for j in range(0, len(ls)):
        if j in completed:
            continue
        try:
            wget.download(ls[j], download_path)
            completed.add(j)
            if j % 20 == 0:  # 每下载20个保存一次进度
                save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)
        except Exception as e:
            print(f"|| {j} err: {e}")
            err_list.append(j)
            continue

    err_log[n] = err_list
    n += 1
    save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)

    # 失败处重新下载
    while len(err_list) > 5:
        final_err_list = []
        print("\n重新下载失败光谱")
        print("Number of err spectra to download:", len(err_list))
        for j in err_list:
            try:
                wget.download(ls[j], download_path)
                completed.add(j)
                save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)
            except Exception as e:
                print(f"|| {j} err: {e}")
                final_err_list.append(j)
                continue

        err_log[n] = final_err_list
        err_list = final_err_list
        n += 1
        save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)

    return err_log

# %%
#创建下载路径的文件夹
os.makedirs(download_path, exist_ok=True)

# 开始下载
error_log = download_spectra(url_txt_path, download_path, progress_file)
# Out:
# Number of spectra to download: 664821
# -1 / unknown|| 5074 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 6048 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 7249 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 9357 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 9700 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 27776 err: HTTP Error 502: Bad Gateway
# || 27777 err: HTTP Error 502: Bad Gateway
# || 27778 err: HTTP Error 502: Bad Gateway
# || 27779 err: HTTP Error 502: Bad Gateway
# || 27780 err: HTTP Error 502: Bad Gateway
# || 27781 err: HTTP Error 502: Bad Gateway
# || 27782 err: HTTP Error 502: Bad Gateway
# || 27783 err: HTTP Error 502: Bad Gateway
# || 27784 err: HTTP Error 502: Bad Gateway
# || 27785 err: HTTP Error 502: Bad Gateway
# || 27786 err: HTTP Error 502: Bad Gateway
# || 27787 err: HTTP Error 502: Bad Gateway
# || 27788 err: HTTP Error 502: Bad Gateway
# || 27789 err: HTTP Error 502: Bad Gateway
# || 27790 err: HTTP Error 502: Bad Gateway
# || 27791 err: HTTP Error 502: Bad Gateway
# || 27792 err: HTTP Error 502: Bad Gateway
# || 27793 err: HTTP Error 502: Bad Gateway
# || 27794 err: HTTP Error 502: Bad Gateway
# || 27795 err: HTTP Error 502: Bad Gateway
# || 27796 err: HTTP Error 502: Bad Gateway
# || 27797 err: HTTP Error 502: Bad Gateway
# || 27798 err: HTTP Error 502: Bad Gateway
# || 27799 err: HTTP Error 502: Bad Gateway
# || 27800 err: HTTP Error 502: Bad Gateway
# || 27801 err: HTTP Error 502: Bad Gateway
# || 27802 err: HTTP Error 502: Bad Gateway
# || 27803 err: HTTP Error 502: Bad Gateway
# || 27804 err: HTTP Error 502: Bad Gateway
# || 27805 err: HTTP Error 502: Bad Gateway
# || 27806 err: HTTP Error 502: Bad Gateway
# || 27807 err: HTTP Error 502: Bad Gateway
# || 27808 err: HTTP Error 502: Bad Gateway
# || 27809 err: HTTP Error 502: Bad Gateway
# || 27810 err: HTTP Error 502: Bad Gateway
# || 27811 err: HTTP Error 502: Bad Gateway
# || 27812 err: HTTP Error 502: Bad Gateway
# || 27813 err: HTTP Error 502: Bad Gateway
# || 27814 err: HTTP Error 502: Bad Gateway
# || 27815 err: HTTP Error 502: Bad Gateway
# || 27816 err: HTTP Error 502: Bad Gateway
# || 27817 err: HTTP Error 502: Bad Gateway
# || 27818 err: HTTP Error 502: Bad Gateway
# || 27819 err: HTTP Error 502: Bad Gateway
# || 27820 err: HTTP Error 502: Bad Gateway
# || 27821 err: HTTP Error 502: Bad Gateway
# || 27822 err: HTTP Error 502: Bad Gateway
# || 27823 err: HTTP Error 502: Bad Gateway
# || 27824 err: HTTP Error 502: Bad Gateway
# -1 / unknown|| 29022 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 32116 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 32986 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 33626 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 37477 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 39394 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 44440 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 46153 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 49770 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 49794 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 52357 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 55966 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 57223 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 58371 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 60973 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 65329 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 73207 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 75777 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 77123 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 77189 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 86790 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 88781 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 90209 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 103106 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 104822 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 105156 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 106478 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 106879 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 107653 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 108419 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 110094 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 110644 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 110986 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 111735 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 112629 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 121201 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 124102 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 124724 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 125181 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 125614 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 126023 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 126782 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 133268 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 137431 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 138307 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 141425 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 151781 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 154171 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 160348 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 168980 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 183179 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 186489 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 202643 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 211758 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 220113 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 222010 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 223023 err: HTTP Error 502: Bad Gateway
# || 223024 err: HTTP Error 502: Bad Gateway
# || 223025 err: HTTP Error 502: Bad Gateway
# || 223026 err: HTTP Error 502: Bad Gateway
# || 223027 err: HTTP Error 502: Bad Gateway
# || 223028 err: HTTP Error 502: Bad Gateway
# || 223029 err: HTTP Error 502: Bad Gateway
# || 223030 err: HTTP Error 502: Bad Gateway
# || 223031 err: HTTP Error 502: Bad Gateway
# || 223032 err: HTTP Error 502: Bad Gateway
# || 223033 err: HTTP Error 502: Bad Gateway
# || 223034 err: HTTP Error 502: Bad Gateway
# || 223035 err: HTTP Error 502: Bad Gateway
# || 223036 err: HTTP Error 502: Bad Gateway
# || 223037 err: HTTP Error 502: Bad Gateway
# || 223038 err: HTTP Error 502: Bad Gateway
# || 223039 err: HTTP Error 502: Bad Gateway
# || 223040 err: HTTP Error 502: Bad Gateway
# || 223041 err: HTTP Error 502: Bad Gateway
# || 223042 err: HTTP Error 502: Bad Gateway
# || 223043 err: HTTP Error 502: Bad Gateway
# || 223044 err: HTTP Error 502: Bad Gateway
# || 223045 err: HTTP Error 502: Bad Gateway
# || 223046 err: HTTP Error 502: Bad Gateway
# || 223047 err: HTTP Error 502: Bad Gateway
# || 223048 err: HTTP Error 502: Bad Gateway
# || 223049 err: HTTP Error 502: Bad Gateway
# || 223050 err: HTTP Error 502: Bad Gateway
# || 223051 err: HTTP Error 502: Bad Gateway
# || 223052 err: HTTP Error 502: Bad Gateway
# || 223053 err: HTTP Error 502: Bad Gateway
# || 223054 err: HTTP Error 502: Bad Gateway
# || 223055 err: HTTP Error 502: Bad Gateway
# || 223056 err: HTTP Error 502: Bad Gateway
# || 223057 err: HTTP Error 502: Bad Gateway
# -1 / unknown|| 231850 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 233634 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 236544 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 242023 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 248080 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 252698 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 253698 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 264547 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 269047 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 281145 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 284337 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 285358 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 289807 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 289992 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 290498 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 294587 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 299216 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 305323 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 306111 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 307430 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 308600 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 308778 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 309137 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 313156 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 314211 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 314245 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 316544 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 321438 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 323630 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 326839 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 326926 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 331432 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 337754 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 338001 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 342732 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 348176 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 348875 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 349536 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 349717 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 351215 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 360920 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 362719 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 368446 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 369326 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 371034 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 374659 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 379018 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 389882 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown|| 392267 err: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>
# -1 / unknown
