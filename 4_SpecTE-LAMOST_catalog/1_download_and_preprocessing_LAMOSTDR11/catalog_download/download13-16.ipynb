# %%
import wget
import os
import pickle
import json

# %%
# # 定义文件路径

# 定义文件路径
url_txt_path = r"G:\Star\4_SpecTE-LAMOST_catalog\1_download_and_preprocessing_LAMOSTDR11\catalog_download\download_url\13-16.txt"     # URL文件
download_path = r"G:\Star\4_SpecTE-LAMOST_catalog\1_download_and_preprocessing_LAMOSTDR11\catalog_download\FITS\13-16"        # 目标下载位置
progress_file = r'G:\Star\4_SpecTE-LAMOST_catalog\1_download_and_preprocessing_LAMOSTDR11\catalog_download\progress\download_progress_13-16.json'    # 保存下载进度log文件（保存进度，用于恢复下载）

# url_txt_path = "./download_url/5-6.txt"
# download_path = "./Fits/5-6"
# progress_file = "./Fits/download_progress_5-6.json"

# %% [markdown]
# # 开始下载

# %%
# 保存下载进程
def save_progress(progress, progress_file):
    with open(progress_file, 'w') as f:
        json.dump(progress, f)

# 加载下载进程
def load_progress(progress_file):
    if os.path.exists(progress_file):
        with open(progress_file, 'r') as f:
            return json.load(f)
    return {'completed': [], 'err_log': {}, 'n': 0}

def download_spectra(url_txt_path, download_path, progress_file):
    with open(url_txt_path, 'r') as f:
        err_list = []
        ls = []

        # 读到链接列表ls
        f.readline()  # 跳过第一行，如果需要
        while True:
            line = f.readline()
            if line:
                ls.append(line.strip())  # 去掉换行符
            else:
                break

    # Number of all spectra
    print("Number of spectra to download:", len(ls))
    
    # 防止出问题
    progress = load_progress(progress_file)
    completed = set(progress['completed'])
    err_log = progress['err_log']
    n = progress['n']

    for j in range(0, len(ls)):
        if j in completed:
            continue
        try:
            wget.download(ls[j], download_path)
            completed.add(j)
            if j % 20 == 0:  # 每下载20个保存一次进度
                save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)
        except Exception as e:
            print(f"|| {j} err: {e}")
            err_list.append(j)
            continue

    err_log[n] = err_list
    n += 1
    save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)

    # 失败处重新下载
    while len(err_list) > 5:
        final_err_list = []
        print("\n重新下载失败光谱")
        print("Number of err spectra to download:", len(err_list))
        for j in err_list:
            try:
                wget.download(ls[j], download_path)
                completed.add(j)
                save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)
            except Exception as e:
                print(f"|| {j} err: {e}")
                final_err_list.append(j)
                continue

        err_log[n] = final_err_list
        err_list = final_err_list
        n += 1
        save_progress({'completed': list(completed), 'err_log': err_log, 'n': n}, progress_file)

    return err_log

# %%
#创建下载路径的文件夹
os.makedirs(download_path, exist_ok=True)

# 开始下载
error_log = download_spectra(url_txt_path, download_path, progress_file)
# Out:
# Number of spectra to download: 664821
# -1 / unknown|| 399281 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 401011 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 462988 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# -1 / unknown|| 465919 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 468991 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 470355 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 476750 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 488015 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 494681 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 495126 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 497893 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 502560 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 505158 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 505723 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 509637 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 515366 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 516031 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 524165 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 527031 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 530167 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 530279 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 531563 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 533579 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 536032 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 536347 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 537830 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 542342 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 547770 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 549083 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 570978 err: HTTP Error 502: Bad Gateway
# || 570979 err: HTTP Error 502: Bad Gateway
# || 570980 err: HTTP Error 502: Bad Gateway
# || 570981 err: HTTP Error 502: Bad Gateway
# || 570982 err: HTTP Error 502: Bad Gateway
# || 570983 err: HTTP Error 502: Bad Gateway
# || 570984 err: HTTP Error 502: Bad Gateway
# || 570985 err: HTTP Error 502: Bad Gateway
# || 570986 err: HTTP Error 502: Bad Gateway
# || 570987 err: HTTP Error 502: Bad Gateway
# || 570988 err: HTTP Error 502: Bad Gateway
# || 570989 err: HTTP Error 502: Bad Gateway
# || 570990 err: HTTP Error 502: Bad Gateway
# || 570991 err: HTTP Error 502: Bad Gateway
# || 570992 err: HTTP Error 502: Bad Gateway
# || 570993 err: HTTP Error 502: Bad Gateway
# || 570994 err: HTTP Error 502: Bad Gateway
# || 570995 err: HTTP Error 502: Bad Gateway
# || 570996 err: HTTP Error 502: Bad Gateway
# || 570997 err: HTTP Error 502: Bad Gateway
# || 570998 err: HTTP Error 502: Bad Gateway
# || 570999 err: HTTP Error 502: Bad Gateway
# || 571000 err: HTTP Error 502: Bad Gateway
# || 571001 err: HTTP Error 502: Bad Gateway
# || 571002 err: HTTP Error 502: Bad Gateway
# || 571003 err: HTTP Error 502: Bad Gateway
# || 571004 err: HTTP Error 502: Bad Gateway
# || 571005 err: HTTP Error 502: Bad Gateway
# || 571006 err: HTTP Error 502: Bad Gateway
# || 571007 err: HTTP Error 502: Bad Gateway
# || 571008 err: HTTP Error 502: Bad Gateway
# || 571009 err: HTTP Error 502: Bad Gateway
# || 571010 err: HTTP Error 502: Bad Gateway
# || 571011 err: HTTP Error 502: Bad Gateway
# || 571012 err: HTTP Error 502: Bad Gateway
# || 571013 err: HTTP Error 502: Bad Gateway
# || 571014 err: HTTP Error 502: Bad Gateway
# || 571015 err: HTTP Error 502: Bad Gateway
# || 571016 err: HTTP Error 502: Bad Gateway
# || 571017 err: HTTP Error 502: Bad Gateway
# || 571018 err: HTTP Error 502: Bad Gateway
# || 571019 err: HTTP Error 502: Bad Gateway
# || 571020 err: HTTP Error 502: Bad Gateway
# || 571021 err: HTTP Error 502: Bad Gateway
# || 571022 err: HTTP Error 502: Bad Gateway
# || 571023 err: HTTP Error 502: Bad Gateway
# || 571024 err: HTTP Error 502: Bad Gateway
# || 571025 err: HTTP Error 502: Bad Gateway
# || 571026 err: HTTP Error 502: Bad Gateway
# || 571027 err: HTTP Error 502: Bad Gateway
# || 571028 err: HTTP Error 502: Bad Gateway
# || 571029 err: HTTP Error 502: Bad Gateway
# || 571030 err: HTTP Error 502: Bad Gateway
# -1 / unknown|| 612635 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 614886 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 624543 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 624596 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 646932 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown|| 651271 err: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
# -1 / unknown
# 重新下载失败光谱
# Number of err spectra to download: 149
# -1 / unknown
