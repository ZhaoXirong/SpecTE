# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import seaborn as sns
import os
import re

# %% [markdown]
# (注意)：在此之前，需要将前面两部分得到的数据交叉匹配，结果存放在match中，接下来开始这一步

# %% [markdown]
# # 将匹配表按信噪比snrg分为多个文件，并分别下载链接
# Dividing the APOGEE-LAMOST cross-match table into intervals according to the signal-to-noise ratio

# %% [markdown]
# ## 读文件

# %%
match = pd.read_csv(r'E:\my_star\raw_data_catalogue_label\match.csv')

# %%
match.columns
# Out:
# Index(['lamost_obsid_1', 'lamost_snrg_1', 'lamost_class_1',
#        'lamost_subclass_1', 'lamost_z_1', 'lamost_ra_1', 'lamost_dec_1',
#        'lamost_logg_1', 'lamost_file_1', 'lamost_obsid_2', 'lamost_snrg_2',
#        'lamost_class_2', 'lamost_subclass_2', 'lamost_z_2', 'lamost_ra_2',
#        'lamost_dec_2', 'lamost_logg_2', 'lamost_file_2', 'GroupID',
#        'GroupSize', 'Separation'],
#       dtype='object')

# %% [markdown]
# ## 定义拆分函数

# %%
folder_path = r'E:\my_star\download\snrg_split'  # 定义保存CSV文件的文件夹路径


def depart_low(i,j):

    snrg=match.iloc[np.where((match["lamost_snrg_1"]>=i)&(match["lamost_snrg_1"]<j))]

    print("snrg_{}_{}".format(i,j)," len:",len(snrg))

    snrg.to_csv(os.path.join(folder_path, "match_low_{}_{}.csv".format(i,j))) 

    return snrg

def depart_high(i,j):

    snrg=match.iloc[np.where((match["lamost_snrg_2"]>=i)&(match["lamost_snrg_2"]<j))]

    print("snrg_{}_{}".format(i,j)," len:",len(snrg))

    snrg.to_csv(os.path.join(folder_path, "match_high_{}_{}.csv".format(i,j))) 

    return snrg

# %%
def depart2_high(i):
    snrg=match.iloc[np.where(match["lamost_snrg_2"]>=i)]
    print("snrg_{}".format(i)," len:",len(snrg))
    snrg.to_csv(os.path.join(folder_path, "match_high_{}.csv".format(i))) 
    return snrg

# %% [markdown]
# ## 进行拆分

# %%
# 将低信噪比数据分为5组
for i in range(5):
    depart_low(10*i,10*(i+1))
# Out:
# snrg_0_10  len: 34978
# snrg_10_20  len: 57745
# snrg_20_30  len: 53511
# snrg_30_40  len: 54145
# snrg_40_50  len: 56304

# %%
# 将高信噪比数据分为3组
depart_high(100,120)
depart_high(120,200)
depart2_high(200)
# Out:
# snrg_100_120  len: 111114
# snrg_120_200  len: 114568
# snrg_200  len: 31001
#         lamost_obsid_1  lamost_snrg_1 lamost_class_1 lamost_subclass_1  \
# 159            2303213          25.70           STAR                F5
# 167            2315019          16.30           STAR                G0
# 176            2316130          24.44           STAR                G0
# 283            3516007           6.83           STAR                F4
# 428            4116177          36.48           STAR                A2
# ...                ...            ...            ...               ...
# 256669       975712126           8.71           STAR                WD
# 256670       989102047           7.05           STAR                WD
# 256672       989412126           7.21           STAR                WD
# 256676       994108032          22.33           STAR                WD
# 256679       994114232           5.03           STAR                WD
#
#          lamost_z_1  lamost_ra_1  lamost_dec_1  lamost_logg_1  \
# 159       -0.000024     3.672660     31.948338          4.107
# 167       -0.000226     4.580477     32.692196            NaN
# 176       -0.000093     3.627918     33.419399          4.270
# 283       -0.000201    19.705949     33.263305          4.045
# 428        0.000027    45.290983     53.801076          3.998
# ...             ...          ...           ...            ...
# 256669     0.000186    97.262963     20.497851      -9999.000
# 256670 -9999.000000   135.222917     21.354368            NaN
# 256672    -0.000277    97.262963     20.497851          6.777
# 256676     0.000266   101.592547     23.168927      -9999.000
# 256679     0.000105    98.320924     23.701794      -9999.000
#
#                                             lamost_file_1  lamost_obsid_2  \
# 159      20111109/B7503/spec-55875-B7503_sp03-213.fits.gz       679410173
# 167      20111109/B7503/spec-55875-B7503_sp15-019.fits.gz       679404187
# 176      20111109/B7503/spec-55875-B7503_sp16-130.fits.gz       679403103
# 283     20111110/M31_021N31_B1/spec-55876-M31_021N31_B...       678308205
# 428     20111112/B87806_1/spec-55878-B87806_1_sp16-177...       685804129
# ...                                                   ...             ...
# 256669  20220128/TD062610N184524H01/spec-59608-TD06261...       882812126
# 256670  20220225/HD090726N225851V02/spec-59636-HD09072...       398008016
# 256672  20220225/TD062610N184524H01/spec-59636-TD06261...       882812126
# 256676  20220305/TD064253N231249K01/spec-59644-TD06425...       758808032
# 256679  20220305/TD064253N231249K01/spec-59644-TD06425...       759714232
#
#         ...  lamost_class_2 lamost_subclass_2 lamost_z_2  lamost_ra_2  \
# 159     ...            STAR                F5  -0.000055     3.672508
# 167     ...            STAR                F9  -0.000211     4.580489
# 176     ...            STAR                F9  -0.000104     3.627797
# 283     ...            STAR                F0  -0.000255    19.705921
# 428     ...            STAR                A1   0.000024    45.290946
# ...     ...             ...               ...        ...          ...
# 256669  ...            STAR                A6   0.000067    97.262963
# 256670  ...            STAR                F5  -0.000148   135.222917
# 256672  ...            STAR                A6   0.000067    97.262963
# 256676  ...            STAR                G5   0.000168   101.592547
# 256679  ...            STAR                A2   0.000070    98.320924
#
#         lamost_dec_2  lamost_logg_2  \
# 159        31.948328          4.205
# 167        32.692202          4.059
# 176        33.419404          4.167
# 283        33.263290          4.057
# 428        53.801231          3.834
# ...              ...            ...
# 256669     20.497851            NaN
# 256670     21.354368          4.068
# 256672     20.497851            NaN
# 256676     23.168927          2.565
# 256679     23.701794            NaN
#
#                                             lamost_file_2  GroupID  GroupSize  \
# 159     20181010/HD002045N325440B01/spec-58402-HD00204...      NaN        NaN
# 167     20181010/HD002045N325440B01/spec-58402-HD00204...     72.0        3.0
# 176     20181010/HD002045N325440B01/spec-58402-HD00204...     76.0        2.0
# 283     20181006/HD011401N342933B01/spec-58398-HD01140...      NaN        NaN
# 428     20181031/TD030224N542147B01/spec-58423-TD03022...      NaN        NaN
# ...                                                   ...      ...        ...
# 256669  20210117/TD062610N184524H01/spec-59232-TD06261...  44600.0        5.0
# 256670  20151230/KP085705N215137V01/spec-57387-KP08570...      NaN        NaN
# 256672  20210117/TD062610N184524H01/spec-59232-TD06261...  44600.0        5.0
# 256676  20191028/TD064253N231249K01/spec-58785-TD06425...  14123.0        4.0
# 256679  20191030/TD064253N231249K01/spec-58787-TD06425...      NaN        NaN
#
#         Separation
# 159       0.465402
# 167       0.043179
# 176       0.363424
# 283       0.100100
# 428       0.563132
# ...            ...
# 256669    0.000000
# 256670    0.000000
# 256672    0.000000
# 256676    0.000000
# 256679    0.000000
#
# [31001 rows x 21 columns]

# %% [markdown]
# # 生成obsid 文件
#
# 这个文件作为下一步下载的目录

# %%
directory_path =  r'E:\my_star\download\snrg_split'
save_path =  r'E:\my_star\download\download_obsid'

file_list = os.listdir(directory_path)

# 遍历文件列表
for filename in file_list:
    file_path= os.path.join(directory_path, filename)  # 当前文件的path
    # 检查是否为文件（而非子目录）
    if os.path.isfile(file_path):
        save_filename = re.sub(r'\.csv$', '.txt', filename)
        save_file_path = os.path.join(save_path,save_filename)
        catalog = pd.read_csv(file_path) 
        

        if 'low' in save_file_path:
            
            observed_ids = set()        
            # 打开文件写入数据
            with open(save_file_path, 'w') as file:
                # 遍历DataFrame的每行
                for obsid in catalog['lamost_obsid_1']:
                    # 检查obsid是否已经在集合中
                    if obsid not in observed_ids:
                        # 如果不在集合中，写入文件并添加到集合中
                        file.write(f'{obsid}\n')
                        observed_ids.add(obsid)  # 将当前obsid添加到集合中，表示已处理
                        
        if 'high' in save_file_path:
            
            observed_ids = set()        
            # 打开文件写入数据
            with open(save_file_path, 'w') as file:
                # 遍历DataFrame的每行
                for obsid in catalog['lamost_obsid_2']:
                    # 检查obsid是否已经在集合中
                    if obsid not in observed_ids:
                        # 如果不在集合中，写入文件并添加到集合中
                        file.write(f'{obsid}\n')
                        observed_ids.add(obsid)  # 将当前obsid添加到集合中，表示已处理

# %%
# Out:
# 'match_0_10.txt'
